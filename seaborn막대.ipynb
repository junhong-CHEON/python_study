# %%
import seaborn as sns
from matplotlib import pyplot as plt
from pandas import DataFrame
import numpy as np

# %%
년도 = [2011,2011,2012,2012,2013,2013,2014,2014,2015,2015,2016,2016,2017,2017,2018,2018, 2019,2019, 2020, 2020]
항목 = ['취업자','실업자','취업자','실업자','취업자','실업자','취업자','실업자','취업자','실업자']*2
인구수 = [3958, 313, 3919, 340, 3761, 300, 2780, 359, 3890, 397, 3950, 425, 4003, 408, 3908, 460, 3953, 437, 3770, 426]
index = [-0.5,0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,7.5,8,8.5,9,9]
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["font.size"] = 16
plt.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(1, 1)
sns.barplot(x = 년도, hue = 항목, y = 인구수, ax = ax)
plt.grid()
plt.title('년도별 취업자 및 실업자')
plt.legend(bbox_to_anchor=(1,1))
for i,v in enumerate(인구수):
    plt.text(index[i], v, '%s' %v)
